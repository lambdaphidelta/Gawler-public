# %%
import rasterio

from rasterio.plot import show

raster = rasterio.open('E:/Gawler/GCAS_Region1A_MAG_TIF/MAG_1A/2018sa009_pacecopper_gcas_region1a_rtp.tif')

show(raster)

# %%
import matplotlib.pyplot as plt

ch2 = raster.read(2)

plt.imshow(ch2)

# %%
ch1.shape
# Out:
# (3610, 4848)

# %%
from skimage import data, io, filters, feature

# %%
binary = ch1 > thresh
plt.imshow(binary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-069a175963c3> in <module>
# ----> 1 binary = ch1 > thresh
#       2 plt.imshow(binary)
#
# NameError: name 'ch1' is not defined

# %%
hist = plt.hist(ch1.ravel())

# %%
edges2 = feature.canny(binary, sigma=3)

# %%
from scipy import ndimage as ndi
im = ndi.gaussian_filter(binary, 2)


#plt.imshow(edges2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3be5225c3c2e> in <module>
#       1 from scipy import ndimage as ndi
# ----> 2 im = ndi.gaussian_filter(binary, 2)
#       3
#       4
#       5 #plt.imshow(edges2)
#
# NameError: name 'binary' is not defined

# %%
plt.imshow(im)

# %%
from skimage.filters import *

# %%
fig, axes = plt.subplots(2, 5)

cmap = plt.cm.gray


image = ch2

def identity(image, **kwargs):
    """Return the original image, ignoring any kwargs."""
    return image

kwargs = {'sigmas': [1]}


fig, axes = plt.subplots(2, 5)
for i, black_ridges in enumerate([1, 0]):
    for j, func in enumerate([identity, meijering, sato, frangi, hessian]):
        kwargs['black_ridges'] = black_ridges
        result = func(image, **kwargs)
        axes[i, j].imshow(result, cmap=cmap, aspect='auto')
        if i == 0:
            axes[i, j].set_title(['Original\nimage', 'Meijering\nneuriteness',
                                  'Sato\ntubeness', 'Frangi\nvesselness',
                                  'Hessian\nvesselness'][j])
        if j == 0:
            axes[i, j].set_ylabel('black_ridges = ' + str(bool(black_ridges)))
        axes[i, j].set_xticks([])
        axes[i, j].set_yticks([])

plt.tight_layout()

# %%
plt.imshow(meijering(image))
